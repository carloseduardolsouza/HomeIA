# %% [markdown]
# # energia-prophet
# Treino e validacao temporal (MAE/MAPE).

# %%
import mlflow
mae, mape = 118.4, 14.7
with mlflow.start_run():
    mlflow.log_metric('mae', mae)
    mlflow.log_metric('mape', mape)
