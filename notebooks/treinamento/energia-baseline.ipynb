# %% [markdown]
# # energia-baseline
# Baseline historico por hora e dia da semana.

# %%
import pandas as pd
df = pd.DataFrame({'ts': pd.date_range('2026-01-01', periods=48, freq='h'), 'potencia_w': 1000})
df['hour'] = df['ts'].dt.hour
df.groupby('hour')['potencia_w'].mean().head()
